# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# load datasets
df_08 = pd.read_csv('clean_08.csv')
df_18 = pd.read_csv('clean_18.csv')

# %%
df_08.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 1  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 2   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 3   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 4   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  7.0      15.0     20.0     17.0                     4
# 1                  7.0      17.0     22.0     19.0                     5
# 2                  7.0      16.0     24.0     19.0                     5
# 3                  7.0      18.0     26.0     21.0                     6
# 4                  7.0      17.0     26.0     20.0                     6
#
#   smartway
# 0       no
# 1       no
# 2       no
# 3      yes
# 4      yes

# %%
df_08.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'veh_class',
#        'air_pollution_score', 'city_mpg', 'hwy_mpg'],
#       dtype='object')

# %%
for col in df_08.columns:
    df_08.rename(columns = {"col" : "new"}) : lambda x:x[:10] + "_2008"
    
df_08.rename(columns={"col" : "new"})

# %%
new_labels = []
for col in df_08.columns:
    if '_2008' in col:
        new_labels.append(col)  
    else:
        new_labels.append(col[:10] + "_2008")
# assign new labels to columns in dataframe
df_08.columns = new_labels

# %%
df_08.columns
# Out:
# Index(['model_2008', 'displ_2008', 'cyl_2008', 'trans_2008', 'drive_2008',
#        'fuel_2008', 'veh_class_2008', 'air_pollut_2008', 'city_mpg_2008',
#        'hwy_mpg_2008', 'cmb_mpg_2008', 'greenhouse_2008', 'smartway_2008'],
#       dtype='object')

# %%
df_08.rename(columns = lambda x : x[:10] + "_2008")
# Out:
#               model_2008_2008  displ_2008_2008  cyl_2008_2008 trans_2008_2008  \
# 0                   ACURA MDX              3.7              6         Auto-S5
# 1                   ACURA RDX              2.3              4         Auto-S5
# 2                    ACURA RL              3.5              6         Auto-S5
# 3                    ACURA TL              3.2              6         Auto-S5
# 4                    ACURA TL              3.5              6         Auto-S5
# 5                    ACURA TL              3.5              6           Man-6
# 6                   ACURA TSX              2.4              4           Man-6
# 7                   ACURA TSX              2.4              4         Auto-S5
# 8            ASTON MARTIN DB9              5.9             12           Man-6
# 9            ASTON MARTIN DB9              5.9             12         Auto-S6
# 10   ASTON MARTIN DB9 Volante              5.9             12           Man-6
# ...

# %%
pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
# merge datasets
df_combined = df_08.merge(df_18, left_on = 'model_2008', right_on = 'model')

# %%
# view to check merge
df_combined.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 1  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 2  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 3  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 4  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
#
#   veh_class_2008  air_pollut_2008  city_mpg_2008  hwy_mpg_2008   ...     \
# 0            SUV              7.0           15.0          20.0   ...
# 1            SUV              7.0           15.0          20.0   ...
# 2            SUV              7.0           15.0          20.0   ...
# 3            SUV              7.0           15.0          20.0   ...
# 4            SUV              7.0           15.0          20.0   ...
#
#         trans  drive      fuel  veh_class  air_pollution_score  city_mpg  \
# ...

# %%
df.columns
# Out:
# Index(['model_2008', 'displ_2008', 'cyl_2008', 'trans_2008', 'drive_2008',
#        'fuel_2008', 'veh_class_2008', 'air_pollut_2008', 'city_mpg_2008',
#        'hwy_mpg_2008', 'cmb_mpg_2008', 'greenhouse_2008', 'smartway_2008',
#        'model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'veh_class',
#        'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
df_combined.to_csv('combined_dataset.csv', index=False)
df = pd.read_csv('combined_dataset.csv')

# %% [markdown]
# 1. Create a new dataframe, model_mpg, that contain the mean combined mpg values in 2008 and 2018 for each unique model
# To do this, group by model and find the mean cmb_mpg_2008 and mean cmb_mpg for each.

# %%
model_mpg_2008 = df.groupby('model_2008')['cmb_mpg_2008'].mean()
model_mpg_2008

model_mpg = df.groupby('model')['cmb_mpg'].mean()
model_mpg

diff = model_mpg -model_mpg_2008


diff.sort_values(axis = 0, ascending = False)
# Out:
# model
# LAND ROVER Range Rover          10.500000
# LINCOLN Navigator                9.500000
# LEXUS LX 570                     7.000000
# BMW M6 Convertible               6.000000
# DODGE Charger                    5.950000
# NISSAN Pathfinder                5.500000
# HYUNDAI Santa Fe                 5.500000
# LAND ROVER Range Rover Sport     5.500000
# BUICK Enclave                    5.500000
# JEEP Grand Cherokee              5.257143
# CADILLAC Escalade                5.000000
# AUDI S4                          4.500000
# NISSAN Armada                    4.500000
# JEEP Wrangler                    4.500000
# NISSAN Frontier                  4.333333
# FORD Fusion                      4.266667
# GMC Yukon 1500                   4.250000
# MASERATI Granturismo             4.000000
# NISSAN Titan                     4.000000
# MAZDA CX-9                       4.000000
# CHEVROLET Tahoe 1500             4.000000
# FORD F150                        3.714286
# ...
